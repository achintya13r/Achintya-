# %%
import numpy as np
a=np.array([10,7])
b=np.array([2,8])
print(a+b)
# Out:
# [12 15]

# %%
import numpy as np
a=np.array([0,9,3])
b=np.array([6,4,6])
print(a+b)
# Out:
# [ 6 13  9]

# %%
X=np.array([
    [2,3],
    [3,4],
    [4,1]
])

# %%
np.dot([5,2],[5,1])
# Out:
# np.int64(27)

# %%
scores=[9.32,8.3,8.2]
print(np.mean(scores))
# Out:
# 8.606666666666667

# %%
w=6
Ir=0.4
for i in range(4):
  w=w-Ir*2*w
  print(w)
# Out:
# 1.1999999999999993
# 0.23999999999999977
# 0.04799999999999993
# 0.009599999999999984
