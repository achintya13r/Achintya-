# %%
for i in range(2):
 for j in range


    (3):
    print (i,j)
# Out:
# 0 0
# 0 1
# 0 2
# 1 0
# 1 1
# 1 2

# %%
for i in range(3):
 for j in range(3):
    print ("*",end="")
 print()
# Out:
# ***
# ***
# ***

# %%
rows=int(input("enter rows"))
cols=int(input("enter columns"))
for i in range(rows):
    for j in range(cols):
         print ("#",end="")
    print()
# Out:
# enter rows2
# enter columns4
# ####
# ####

# %%
for i in range(2):
  for j in range(3):
    print("i=","j=",j)
    print(i,j)
# Out:
# i= j= 0
# 0 0
# i= j= 1
# 0 1
# i= j= 2
# 0 2
# i= j= 0
# 1 0
# i= j= 1
# 1 1
# i= j= 2
# 1 2

# %%
for i in range(1,5):
  for j in range(1,5):
    print(i*j, end="\t")
    print()
# Out:
# 1
# 2
# 3
# 4
# 2
# 4
# 6
# 8
# 3
# 6
# 9
# 12
# 4
# 8
# 12
# 16

# %%
for i in range(2):
  j=0
  while j<2:
    print(i,j)
    j+=1
# Out:
# 0 0
# 0 1
# 1 0
# 1 1
