# %%
word="achintya"
print(word[5])
print(word[4])
# Out:
# t
# n

# %%
word="achintya"
print(word[-7])
print(word[-3])
# Out:
# c
# t

# %%
text="achintya"
print(text[0:4])
# Out:
# achi

# %%
name="Achintya"
print(len(name))
# Out:
# 8

# %%
name="kumar raj"
print("kumar raj".upper())
# Out:
# KUMAR RAJ

# %%
name="kumar RAJ"
print("kumar RAJ".lower())
# Out:
# kumar raj

# %%
name="kumar RAJ"
print("kumar RAJ".title())
# Out:
# Kumar Raj

# %%
data="  ishi  "
print(data.strip())
# Out:
# ishi

# %%
data= "  sushi  "
print(data)
# Out:
#   sushi

# %%
data=" gurl"
print(data.lstrip())
# Out:
# gurl

# %%
msg="I love studying"
print(msg.replace("studying", "sleeping"))
# Out:
# I love sleeping

# %%
email="achintyashetty13gmail.com"
print("@" in email)
# Out:
# False

# %%
sentence="you are very cool"
words=sentence.split()
print(words)
# Out:
# ['you', 'are', 'very', 'cool']

# %%
words=['you', 'are', 'very', 'cool']
print("".join(words))
# Out:
# youareverycool

# %%
first="are"
second="you"
third="fine"
print(first+" "+second+" "+third)
# Out:
# are you fine

# %%
name ="reddy"
age =21
print("my friend name is (name) and he is (21) years old")
# Out:
# my friend name is (name) and he is (21) years old

# %%
text="Nikitha"
print(text.count("i"))
# Out:
# 2
