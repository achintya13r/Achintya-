# %%
text="python"
print(len(text))
# Out:
# 6

# %%
text="python"
print(text[::-1])
# Out:
# nohtyp

# %%
text=str(input("enter the word"))
if (text==text[::-1]):
    print("palindrome")
else:
    print("not palindrome")
# Out:
# enter the wordStart
# not palindrome

# %%
list_1=[4,5,6,7]
list_2=[4,5,3,1]
print(set(list_1) & set(list_2))
# Out:
# {4, 5}
