# %%
file=open("attendance.text","w")
file.write("bhagavan_p \n rahul_p \n achintya_p \n dhanusha_p")
file.close()
file=open("attendance.text","r")
content=file.read()
print(content)
file.close()
# Out:
# bhagavan_p
#  rahul_p
#  achintya_p
#  dhanusha_p

# %%
file=open("attendance.text","a")
file.write("\n harish_a")
file.close()
file=open("attendance.text","r")
content=file.read()
print(content)
file.close()
# Out:
# bhagavan_p
#  rahul_p
#  achintya_p
#  dhanusha_p
#  harish_a

# %%
file=open("journal.text","a")
file.write("date:2-1-26 \n our clz was completed early today")
file.close()
file=open("journal.text","r")
content=file.read()
print(content)
file.close()
# Out:
# date:2-1-26
#  hi guyzdate:2-1-26
#  our clz was completed early today

# %%
file=open("expenditure.text","w")
file.write("1-1-26 $250 food \n 2-1-26 $30 pen \n 3-1-26 $550 food")
file.close()
file=open("expenditure.text","r")
content=file.read()
print(content)
file.close()
# Out:
# 1-1-26 $250 food
#  2-1-26 $30 pen
#  3-1-26 $550 food
