# %%
fruits=["pear","kiwi","alphanso","melon"]
print(fruits[3])
# Out:
# melon

# %%
vegetables=["okra","onion","carrot"]
vegetables.append("cabbage")
print(vegetables)
# Out:
# ['okra', 'onion', 'carrot', 'cabbage']

# %%
vegetables=["okra","brinjal","onion","carrot"]
vegetables.append("cabbage")
vegetables.remove("brinjal")
vegetables.sort()
print(vegetables)
# Out:
# ['cabbage', 'carrot', 'okra', 'onion']

# %%
students=[]
students.append("Achi")
students.append("Niki")
students.append("Rupi")
students.append("Aish")
print(students)
students.sort()
print(students)
# Out:
# ['Achi', 'Niki', 'Rupi', 'Aish']
# ['Achi', 'Aish', 'Niki', 'Rupi']

# %%
coordinates=(5,10)
print (coordinates[0])
# Out:
# 5

# %%
numbers={1,3,4,5,2,3,1,1,1,4,6,7,4}
print(numbers)
numbers.remove(3)
print(numbers)
numbers.add(10)
print(numbers)
# Out:
# {1, 2, 3, 4, 5, 6, 7}
# {1, 2, 4, 5, 6, 7}
# {1, 2, 4, 5, 6, 7, 10}

# %%
student={
    "name":"Ach",
    "age":21,
    "course":["ABM","el"],
}
print(student["course"])
# Out:
# ['ABM', 'el']

# %%
marks={
    "social":99,
    "science":95,
}
marks["VARC"]=99
print(marks)
# Out:
# {'social': 99, 'science': 95, 'VARC': 99}
